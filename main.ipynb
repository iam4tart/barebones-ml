# %%
import torch
import barebones
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\torch\_ops.py:1503, in _Ops.load_library(self, path)
#    1502 try:
# -> 1503     ctypes.CDLL(path)
#    1504 except Exception as e:
#
# File c:\Python313\Lib\ctypes\__init__.py:390, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     389 if handle is None:
# --> 390     self._handle = _dlopen(self._name, mode)
#     391 else:
#
# OSError: [WinError 1114] A dynamic link library (DLL) initialization routine failed
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 2
#       1 import torch
# ----> 2 import barebones
#
# File d:\Hackaton\BULUPRYNT\scene-graph\daily-core\barebones\__init__.py:14
# ...
